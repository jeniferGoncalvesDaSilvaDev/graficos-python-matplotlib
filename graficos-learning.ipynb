# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/graficos-python-matplotlib/blob/main/graficos-learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subplots

# %%
#graficos de quantidade de marmitas, vendidas diariamente, em 5 dias, dentro de uma semana, de 3 empresas diferentes
#Empresa: Beta Log
from matplotlib import pyplot as plt
numero_marmitas_beta_log=[12,15,7,10,10]
dias_beta_log=[1,2,3,4,5]
#tamanho do grafico
figura=plt.figure(figsize=(30,4))
#titulos na figura, que vai ser o titulo dos graficos
figura.suptitle('Análise de gráficos de vendas de marmitas')
#para plotar o primeiro gráfico
#subplot, pega o numero de linhas ou colunas, posiçao e eixo na figura que os graficos, vao ser plotados
figura.add_subplot(131)
plt.xlabel('Dias')
plt.ylabel('Número de marmitas vendidas para Beta Log')
plt.plot(dias_beta_log, numero_marmitas_beta_log,label='Número de marmitas vendidas')

plt.legend()
plt.title('Gráfico de marmitas vendidas da empresa Beta Log')
#Empresa Tag Log
numero_marmitas_tag_log=[20,12,15,8,17]
dias_tag_log=[1,2,3,4,5]
#nos gráficos posteriores, tendo ja definido as dimensoes da figura, agora é so subplotar!
figura.add_subplot(133)
plt.xlabel('Dias')
plt.ylabel('Número de marmitas para Tag Log')
plt.plot(dias_tag_log,numero_marmitas_tag_log, label='Número de mamritas vendidas')
plt.legend()
plt.title('Gráfico de marmitas vendidas da empresa Tag Log')
#Empresa: Pescados
marmitas_pescados=[10,9,14,5,15]
dias_pescados=[1,2,3,4,5]
figura.add_subplot(132)
plt.xlabel('Dias')
plt.ylabel('Número de marmitas vendidas para Pescados')
plt.plot(dias_pescados,marmitas_pescados,label="Número de marmitas vendidas")
plt.legend()
plt.title("Gráfico de marmitas vendidas da empresa Pescados")
#salvando os graficos
plt.savefig('grafico-vendas-marmitas.png')
plt.show(figura)

# %%
#aplicação dos coneitos aprendidos
#analise de dados com kaggle da bolsa de valores
#https://www.kaggle.com/mattiuzc/stock-exchange-data
import pandas as pd
cotacao_df= pd.read_csv('indexData.csv')
display(cotacao_df)
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA  1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA  1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA  1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA  1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100  2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100  2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100  2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100  2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100  2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
#analise de data, de onde eh a bolsa, no caso em Wall Street em Nova e seu fechamento
#pegando as cotaçoes em Nova York, sua Data e seu fechamento
cotacao_df_01= cotacao_df[['Index','Date','Close']]
display(cotacao_df_01)
# Out:
#        Index        Date        Close
# 0        NYA  1965-12-31   528.690002
# 1        NYA  1966-01-03   527.210022
# 2        NYA  1966-01-04   527.840027
# 3        NYA  1966-01-05   531.119995
# 4        NYA  1966-01-06   532.070007
# ...      ...         ...          ...
# 112452  N100  2021-05-27  1247.069946
# 112453  N100  2021-05-28  1256.599976
# 112454  N100  2021-05-31  1248.930054
# 112455  N100  2021-06-01  1258.579956
# 112456  N100  2021-06-02  1263.619995
#
# [112457 rows x 3 columns]

# %%
#o metodo loc, localiza valores a partir de colunas
df_remove=cotacao_df_01.loc[(cotacao_df_01['Index']!='NYA')]
#o metodo drpo, exclui dados
cotacao_final_df= cotacao_df_01.drop(df_remove.index)
display(cotacao_final_df)
#fatiamento do dataframe
#pega desde a linha 13900 ate o final
cotacao_final_df=cotacao_final_df[13900:]
display(cotacao_final_df)
# Out:
#       Index        Date         Close
# 0       NYA  1965-12-31    528.690002
# 1       NYA  1966-01-03    527.210022
# 2       NYA  1966-01-04    527.840027
# 3       NYA  1966-01-05    531.119995
# 4       NYA  1966-01-06    532.070007
# ...     ...         ...           ...
# 13943   NYA  2021-05-24  16464.689450
# 13944   NYA  2021-05-25  16390.189450
# 13945   NYA  2021-05-26  16451.960940
# 13946   NYA  2021-05-27  16531.949220
# 13947   NYA  2021-05-28  16555.660160
#
# [13948 rows x 3 columns]
#       Index        Date        Close
# 13900   NYA  2021-03-23  15346.53027
# 13901   NYA  2021-03-24  15276.55957
# 13902   NYA  2021-03-25  15410.37012
# 13903   NYA  2021-03-26  15682.54004
# 13904   NYA  2021-03-29  15611.87988
# 13905   NYA  2021-03-30  15626.11035
# 13906   NYA  2021-03-31  15601.74023
# 13907   NYA  2021-04-01  15751.70020
# 13908   NYA  2021-04-05  15870.33984
# 13909   NYA  2021-04-06  15877.95996
# 13910   NYA  2021-04-07  15838.84961
# ...

# %%
#ls é estilo de linha
#lw é largura de linha
plt.plot(cotacao_final_df['Date'], cotacao_final_df['Close'], label="NYA",ls="--",lw="2")
plt.legend(loc=2,fontsize=18)
plt.ylabel("Fechamento de ações de NYA")
plt.xlabel("Data")
plt.title("Gráfico histórico de cotação da bolsa NYA")
#intervalo de tempo
#ticks é intervalo no gráfico
plt.xticks(["2021-03-23","2021-05-28"])
plt.show()
